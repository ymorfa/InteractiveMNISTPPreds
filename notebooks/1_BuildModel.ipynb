# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
# Cargar el dataset MNIST
(train_X, train_y), (test_X, test_y) = mnist.load_data()

# Normalizar los datos de entrada
train_X = train_X / 255.0
test_X = test_X / 255.0

# Convertir las etiquetas a one-hot encoding
train_y = to_categorical(train_y, num_classes=10)
test_y = to_categorical(test_y, num_classes=10)

# %%
# Crear el modelo
model = Sequential([
    Flatten(input_shape=(28, 28)),  
    Dense(25, activation='relu'),  
    Dense(25, activation='tanh'),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# c:\Users\melborges\OneDrive\Documents\Yamil\InteractiveMNISTPPreds\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 25)             │        19,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 25)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,535 (80.21 KB)
#  Trainable params: 20,535 (80.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint(
    filepath='../src/models/2L25N_softmax_model.keras', 
    monitor='val_accuracy',   
    save_best_only=True,     
    mode='max',         
    verbose=1      
)

# %%
# Compilar el modelo
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Entrenar el modelo
model.fit(train_X, train_y, epochs=50, batch_size=32, validation_split=0.2, callbacks=[checkpoint] )
# Out:
# Epoch 1/50
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8034 - loss: 0.7273
# Epoch 1: val_accuracy improved from -inf to 0.94142, saving model to ../src/models/2L25N_softmax_model.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8037 - loss: 0.7260 - val_accuracy: 0.9414 - val_loss: 0.2083
# Epoch 2/50
# 1477/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9440 - loss: 0.1884
# Epoch 2: val_accuracy improved from 0.94142 to 0.95067, saving model to ../src/models/2L25N_softmax_model.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9441 - loss: 0.1883 - val_accuracy: 0.9507 - val_loss: 0.1758
# Epoch 3/50
# 1471/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9548 - loss: 0.1486
# Epoch 3: val_accuracy improved from 0.95067 to 0.95367, saving model to ../src/models/2L25N_softmax_model.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9549 - loss: 0.1486 - val_accuracy: 0.9537 - val_loss: 0.1569
# Epoch 4/50
# 1466/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9638 - loss: 0.1213
# Epoch 4: val_accuracy improved from 0.95367 to 0.95700, saving model to ../src/models/2L25N_softmax_model.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9638 - loss: 0.1214 - val_accuracy: 0.9570 - val_loss: 0.1455
# Epoch 5/50
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9678 - loss: 0.1088
# Epoch 5: val_accuracy improved from 0.95700 to 0.95942, saving model to ../src/models/2L25N_softmax_model.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9678 - loss: 0.1089 - val_accuracy: 0.9594 - val_loss: 0.1395
# Epoch 6/50
# 1485/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.1009
# Epoch 6: val_accuracy did not improve from 0.95942
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9700 - loss: 0.1010 - val_accuracy: 0.9558 - val_loss: 0.1488
# Epoch 7/50
# 1462/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9708 - loss: 0.0978
# Epoch 7: val_accuracy improved from 0.95942 to 0.96192, saving model to ../src/models/2L25N_softmax_model.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9708 - loss: 0.0978 - val_accuracy: 0.9619 - val_loss: 0.1326
# Epoch 8/50
# 1467/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9748 - loss: 0.0843
# Epoch 8: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9748 - loss: 0.0844 - val_accuracy: 0.9586 - val_loss: 0.1398
# Epoch 9/50
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9771 - loss: 0.0759
# Epoch 9: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9771 - loss: 0.0759 - val_accuracy: 0.9604 - val_loss: 0.1356
# Epoch 10/50
# 1450/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9790 - loss: 0.0722
# Epoch 10: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9790 - loss: 0.0724 - val_accuracy: 0.9593 - val_loss: 0.1393
# Epoch 11/50
# 1474/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9798 - loss: 0.0650
# Epoch 11: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9797 - loss: 0.0651 - val_accuracy: 0.9613 - val_loss: 0.1395
# Epoch 12/50
# 1464/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9809 - loss: 0.0653
# Epoch 12: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9809 - loss: 0.0653 - val_accuracy: 0.9612 - val_loss: 0.1367
# Epoch 13/50
# 1469/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9803 - loss: 0.0636
# Epoch 13: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9803 - loss: 0.0636 - val_accuracy: 0.9608 - val_loss: 0.1384
# Epoch 14/50
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9836 - loss: 0.0553
# Epoch 14: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9836 - loss: 0.0553 - val_accuracy: 0.9616 - val_loss: 0.1388
# Epoch 15/50
# 1489/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9848 - loss: 0.0537
# Epoch 15: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9848 - loss: 0.0537 - val_accuracy: 0.9611 - val_loss: 0.1427
# Epoch 16/50
# 1475/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9843 - loss: 0.0519
# Epoch 16: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9843 - loss: 0.0520 - val_accuracy: 0.9602 - val_loss: 0.1472
# Epoch 17/50
# 1483/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9863 - loss: 0.0457
# Epoch 17: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9863 - loss: 0.0458 - val_accuracy: 0.9606 - val_loss: 0.1450
# Epoch 18/50
# 1490/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9852 - loss: 0.0475
# Epoch 18: val_accuracy did not improve from 0.96192
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9852 - loss: 0.0475 - val_accuracy: 0.9588 - val_loss: 0.1494
# Epoch 19/50
# 1490/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.0459
# Epoch 19: val_accuracy improved from 0.96192 to 0.96275, saving model to ../src/models/2L25N_softmax_model.keras
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9867 - loss: 0.0459 - val_accuracy: 0.9628 - val_loss: 0.1378
# Epoch 20/50
# 1472/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9895 - loss: 0.0367
# Epoch 20: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9894 - loss: 0.0369 - val_accuracy: 0.9605 - val_loss: 0.1499
# Epoch 21/50
# 1462/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9874 - loss: 0.0412
# Epoch 21: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9873 - loss: 0.0413 - val_accuracy: 0.9617 - val_loss: 0.1498
# Epoch 22/50
# 1488/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0368
# Epoch 22: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9890 - loss: 0.0368 - val_accuracy: 0.9595 - val_loss: 0.1556
# Epoch 23/50
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9901 - loss: 0.0347
# Epoch 23: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9901 - loss: 0.0348 - val_accuracy: 0.9603 - val_loss: 0.1534
# Epoch 24/50
# 1491/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9899 - loss: 0.0342
# Epoch 24: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9899 - loss: 0.0342 - val_accuracy: 0.9610 - val_loss: 0.1543
# Epoch 25/50
# 1481/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9891 - loss: 0.0373
# Epoch 25: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9891 - loss: 0.0373 - val_accuracy: 0.9605 - val_loss: 0.1543
# Epoch 26/50
# 1464/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0311
# Epoch 26: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9912 - loss: 0.0312 - val_accuracy: 0.9597 - val_loss: 0.1595
# Epoch 27/50
# 1458/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.0326
# Epoch 27: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9919 - loss: 0.0326 - val_accuracy: 0.9603 - val_loss: 0.1646
# Epoch 28/50
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0312
# Epoch 28: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9901 - loss: 0.0312 - val_accuracy: 0.9623 - val_loss: 0.1568
# Epoch 29/50
# 1480/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9927 - loss: 0.0259
# Epoch 29: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9927 - loss: 0.0260 - val_accuracy: 0.9593 - val_loss: 0.1658
# Epoch 30/50
# 1493/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0294
# Epoch 30: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9917 - loss: 0.0294 - val_accuracy: 0.9582 - val_loss: 0.1737
# Epoch 31/50
# 1484/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9905 - loss: 0.0303
# Epoch 31: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9905 - loss: 0.0303 - val_accuracy: 0.9616 - val_loss: 0.1613
# Epoch 32/50
# 1477/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9931 - loss: 0.0245
# Epoch 32: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.0245 - val_accuracy: 0.9603 - val_loss: 0.1672
# Epoch 33/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0270
# Epoch 33: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9921 - loss: 0.0270 - val_accuracy: 0.9619 - val_loss: 0.1693
# Epoch 34/50
# 1466/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0263
# Epoch 34: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9917 - loss: 0.0263 - val_accuracy: 0.9617 - val_loss: 0.1690
# Epoch 35/50
# 1474/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9936 - loss: 0.0227
# Epoch 35: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9935 - loss: 0.0227 - val_accuracy: 0.9620 - val_loss: 0.1701
# Epoch 36/50
# 1499/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0253
# Epoch 36: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9923 - loss: 0.0253 - val_accuracy: 0.9595 - val_loss: 0.1840
# Epoch 37/50
# 1483/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9938 - loss: 0.0220
# Epoch 37: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9938 - loss: 0.0220 - val_accuracy: 0.9588 - val_loss: 0.1858
# Epoch 38/50
# 1463/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0192
# Epoch 38: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9944 - loss: 0.0193 - val_accuracy: 0.9578 - val_loss: 0.1905
# Epoch 39/50
# 1483/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0218
# Epoch 39: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9932 - loss: 0.0218 - val_accuracy: 0.9589 - val_loss: 0.1916
# Epoch 40/50
# 1496/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0188
# Epoch 40: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9944 - loss: 0.0188 - val_accuracy: 0.9603 - val_loss: 0.1821
# Epoch 41/50
# 1498/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9945 - loss: 0.0185
# Epoch 41: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9945 - loss: 0.0185 - val_accuracy: 0.9597 - val_loss: 0.1918
# Epoch 42/50
# 1479/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9939 - loss: 0.0201
# Epoch 42: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9939 - loss: 0.0201 - val_accuracy: 0.9594 - val_loss: 0.1959
# Epoch 43/50
# 1463/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9953 - loss: 0.0164
# Epoch 43: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9952 - loss: 0.0165 - val_accuracy: 0.9602 - val_loss: 0.1902
# Epoch 44/50
# 1471/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9939 - loss: 0.0198
# Epoch 44: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9939 - loss: 0.0198 - val_accuracy: 0.9607 - val_loss: 0.1872
# Epoch 45/50
# 1487/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0141
# Epoch 45: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9964 - loss: 0.0141 - val_accuracy: 0.9596 - val_loss: 0.2026
# Epoch 46/50
# 1477/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9936 - loss: 0.0201
# Epoch 46: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9936 - loss: 0.0201 - val_accuracy: 0.9582 - val_loss: 0.2030
# Epoch 47/50
# 1478/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0165
# Epoch 47: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9951 - loss: 0.0165 - val_accuracy: 0.9549 - val_loss: 0.2245
# Epoch 48/50
# 1467/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9955 - loss: 0.0146
# Epoch 48: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9955 - loss: 0.0146 - val_accuracy: 0.9597 - val_loss: 0.2045
# Epoch 49/50
# 1478/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9953 - loss: 0.0158
# Epoch 49: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9953 - loss: 0.0158 - val_accuracy: 0.9597 - val_loss: 0.2007
# Epoch 50/50
# 1495/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9965 - loss: 0.0125
# Epoch 50: val_accuracy did not improve from 0.96275
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9965 - loss: 0.0125 - val_accuracy: 0.9607 - val_loss: 0.2066

# %%
# Load Model
from keras.models import load_model

model = load_model('../src/models/2L25N_softmax_model.keras')

# Evaluar el modelo
test_loss, test_acc = model.evaluate(test_X, test_y)
print(f"Precisión en el conjunto de prueba: {test_acc * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9633 - loss: 0.1352
# Precisión en el conjunto de prueba: 96.70%

# %%
import matplotlib.pyplot as plt
import numpy as np
import io

class Neuron():
    def __init__(self, x, y, activation):
        self.x = x
        self.y = y
        self.activation = activation


    def draw(self, neuron_radius):

        if self.activation > 1:
            color_intensity = 1
            red = 0
            green = 0
            blue = 1
        elif self.activation < 0:
            color_intensity = abs(self.activation)
            red = 1
            green = 0
            blue = 0
        else:
            color_intensity = self.activation
            red = 0
            green = 1
            blue = 0
        
        circle = plt.Circle(
            (self.x, self.y), 
            radius=neuron_radius, 
            edgecolor="black", 
            linewidth=1.5, 
            fill=True, 
            facecolor= (red, green, blue, color_intensity)
        )
        
        plt.gca().add_patch(circle)



class Layer():
    def __init__(self, network, number_of_neurons, activation,  number_of_neurons_in_widest_layer):
        self.vertical_distance_between_layers = 10
        self.horizontal_distance_between_neurons = 3
        self.neuron_radius = 1.5
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.previous_layer = self.__get_previous_layer(network)
        self.y = self.__calculate_layer_y_position()
        self.neurons = self.__intialise_neurons(number_of_neurons, activation)

    def __intialise_neurons(self, number_of_neurons, activation):
        neurons = []
        x = self.__calculate_left_margin_so_layer_is_centered(number_of_neurons)
        for iteration in range(number_of_neurons):
            neuron = Neuron(x, self.y, activation[iteration])
            neurons.append(neuron)
            x += self.horizontal_distance_between_neurons
        return neurons

    def __calculate_left_margin_so_layer_is_centered(self, number_of_neurons):
        return self.horizontal_distance_between_neurons * (self.number_of_neurons_in_widest_layer - number_of_neurons) / 2

    def __calculate_layer_y_position(self):
        if self.previous_layer:
            return self.previous_layer.y + self.vertical_distance_between_layers
        else:
            return 0

    def __get_previous_layer(self, network):
        if len(network.layers) > 0:
            return network.layers[-1]
        else:
            return None
        

    def __line_between_two_neurons(self, neuron1, neuron2):
        # Determina si la línea conecta hacia arriba o hacia abajo
        if neuron2.y > neuron1.y:
            # Conexión hacia arriba
            start_x, start_y = neuron1.x, neuron1.y + self.neuron_radius
            end_x, end_y = neuron2.x, neuron2.y - self.neuron_radius
        else:
            # Conexión hacia abajo
            start_x, start_y = neuron1.x, neuron1.y - self.neuron_radius
            end_x, end_y = neuron2.x, neuron2.y + self.neuron_radius
        
        color_intensity = 0.1 #neuron1.activation  
        line_color = (0, 0, 1, color_intensity)
        
        # Dibuja la línea entre los puntos ajustados
        line = plt.Line2D((start_x, end_x), (start_y, end_y), color=line_color, linewidth=1)
        plt.gca().add_line(line)


    def draw(self, layerType=0):
        for neuron in self.neurons:
            neuron.draw( self.neuron_radius )
            if self.previous_layer:
                for previous_layer_neuron in self.previous_layer.neurons:
                    self.__line_between_two_neurons(neuron, previous_layer_neuron)
        # write Text
        x_text = self.number_of_neurons_in_widest_layer * self.horizontal_distance_between_neurons


        # if layerType == 0:
        #     plt.text(x_text, self.y, 'Input Layer', fontsize = 12)
        if layerType == -1:
            plt.text(x_text, self.y, 'Output Layer', fontsize = 12)
            for idx, neuron in enumerate(self.neurons):
                plt.text(neuron.x-self.neuron_radius/2, neuron.y + self.neuron_radius * 1.5, str(idx), fontsize=15)
        else:
            plt.text(x_text, self.y, 'Hidden Layer '+str(layerType + 1), fontsize = 12)

class NeuralNetwork():
    def __init__(self, number_of_neurons_in_widest_layer):
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.layers = []
        self.layertype = 0

    def add_layer(self, number_of_neurons, activation):
        layer = Layer(self, number_of_neurons, activation, self.number_of_neurons_in_widest_layer)
        self.layers.append(layer)

    def draw(self):
        img_stream = io.BytesIO()
        plt.figure(figsize=(10, 8))
        for i in range( len(self.layers) ):
            layer = self.layers[i]
            if i == len(self.layers)-1:
                i = -1
            layer.draw( i )

        plt.axis('scaled')
        plt.axis('off')


        plt.savefig(img_stream, format='png',  bbox_inches='tight')
        img_stream.seek(0) 
        plt.close()
        return img_stream

class DrawNN():
    def __init__( self, model, input ):
        self.input = input
        self.activations = [self.input]
        self.neural_network = []

        for i, layer in enumerate(model.layers):
            self.activations.append(layer(self.activations[-1]))
            if i > 0:
                self.neural_network.append( self.activations[-1].shape[1]) 
        
        self.activations = self.activations[-len(self.neural_network):]

    def draw( self ):
        widest_layer = max( self.neural_network )
        network = NeuralNetwork( widest_layer )

        
        for output_shape, activation in zip(self.neural_network, self.activations):
            network.add_layer(output_shape,  np.array(activation)[0])
        img_stream = network.draw()
        return img_stream

# %%
from PIL import Image

input = np.expand_dims(test_X[1], axis=0)
network = DrawNN( model, input )
img_stream = network.draw()
img = Image.open(img_stream)
img.show()
